# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Muhammad Reza Pahlevi Harahap]
# - **Email:** [M156B4KY3035@bangkit.academy]
# - **ID Dicoding:** [reza_harahap]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# Berapa jumlah pelanggan yang menyewa sepeda selama hari kerja setiap bulan?
# Apakah musim berdampak pada jumlah penyewaan sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in c:\users\user\appdata\local\programs\orange\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\orange\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# pada tahap ini dilakukan pengambilan data dan disimpan kedalam variabel df setelah itu menampilkan isi dari data tersebut

# %%
df = pd.read_csv("C:\Bangkit sukses\submission\hour.csv")
df.head(20)
# Out:
#     instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1   0        0        6           0
# 1         2  2011-01-01       1   0     1   1        0        6           0
# 2         3  2011-01-01       1   0     1   2        0        6           0
# 3         4  2011-01-01       1   0     1   3        0        6           0
# 4         5  2011-01-01       1   0     1   4        0        6           0
# 5         6  2011-01-01       1   0     1   5        0        6           0
# 6         7  2011-01-01       1   0     1   6        0        6           0
# 7         8  2011-01-01       1   0     1   7        0        6           0
# 8         9  2011-01-01       1   0     1   8        0        6           0
# 9        10  2011-01-01       1   0     1   9        0        6           0
# 10       11  2011-01-01       1   0     1  10        0        6           0
# 11       12  2011-01-01       1   0     1  11        0        6           0
# 12       13  2011-01-01       1   0     1  12        0        6           0
# 13       14  2011-01-01       1   0     1  13        0        6           0
# 14       15  2011-01-01       1   0     1  14        0        6           0
# 15       16  2011-01-01       1   0     1  15        0        6           0
# 16       17  2011-01-01       1   0     1  16        0        6           0
# 17       18  2011-01-01       1   0     1  17        0        6           0
# 18       19  2011-01-01       1   0     1  18        0        6           0
# 19       20  2011-01-01       1   0     1  19        0        6           0
#
#     weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0            1  0.24  0.2879  0.81     0.0000       3          13   16
# 1            1  0.22  0.2727  0.80     0.0000       8          32   40
# 2            1  0.22  0.2727  0.80     0.0000       5          27   32
# 3            1  0.24  0.2879  0.75     0.0000       3          10   13
# 4            1  0.24  0.2879  0.75     0.0000       0           1    1
# 5            2  0.24  0.2576  0.75     0.0896       0           1    1
# 6            1  0.22  0.2727  0.80     0.0000       2           0    2
# 7            1  0.20  0.2576  0.86     0.0000       1           2    3
# 8            1  0.24  0.2879  0.75     0.0000       1           7    8
# 9            1  0.32  0.3485  0.76     0.0000       8           6   14
# 10           1  0.38  0.3939  0.76     0.2537      12          24   36
# 11           1  0.36  0.3333  0.81     0.2836      26          30   56
# 12           1  0.42  0.4242  0.77     0.2836      29          55   84
# 13           2  0.46  0.4545  0.72     0.2985      47          47   94
# 14           2  0.46  0.4545  0.72     0.2836      35          71  106
# 15           2  0.44  0.4394  0.77     0.2985      40          70  110
# 16           2  0.42  0.4242  0.82     0.2985      41          52   93
# 17           2  0.44  0.4394  0.82     0.2836      15          52   67
# 18           3  0.42  0.4242  0.88     0.2537       9          26   35
# 19           3  0.42  0.4242  0.88     0.2537       6          31   37

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Setelah tahap pengambilan dan penampilan data selesai, langkah selanjutnya adalah melakukan pengecekan terhadap integritas dan kevalidan data yang telah diperoleh. Pada tahap ini, dilakukan serangkaian proses verifikasi dan analisis terhadap data untuk memastikan kualitasnya.
#
# dilakukan pengecekan melalui informasi  dari dataset yang dimiliki, seperti jumlah baris dan kolom dan tipe data dari setiap kolom
# Selanjutnya dilakukan identifikasi terhadap adanya duplikat dalam dataset yang dapat mempengaruhi hasil analisis. Kemudian, dilakukan deteksi jumlah nilai yang kosong atau hilang dalam dataset. Hal ini dapat dilakukan dengan menghitung jumlah nilai kosong untuk setiap atribut atau kolom.Terakhir, dilakukan identifikasi terhadap outliers atau nilai ekstrem yang tidak biasa dalam dataset yang mungkin mempengaruhi hasil analisis secara negatif.
# tahap pengecekan data ini sangat penting untuk memastikan \kualitas data yang akan digunakan dalam proses analisis lebih lanjut, sehingga hasil yang dihasilkan menjadi lebih akurat dan dapat diandalkan dalam pengambilan keputusan.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Box Plot
df.boxplot(column=['season'])
plt.show()

# Menghitung IQR
Q1 = df['season'].quantile(0.25)
Q3 = df['season'].quantile(0.75)
IQR = Q3 - Q1

# Menentukan batas bawah dan atas
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Menampilkan outlier
outliers = df[(df['season'] < lower_bound) | (df['season'] > upper_bound)]
print("Outlier:")
print(outliers)
# Out:
# Outlier:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, hr, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
df['season'].value_counts()
# Out:
# 3    4496
# 2    4409
# 1    4242
# 4    4232
# Name: season, dtype: int64

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# langkah selanjutnya adalah melakukan pembersihan data. Meskipun tidak ada masalah besar seperti duplikat atau outliers, tetapi terdapat n tipe data dari kolom "dteday" yang tidak sesuai dengan fungsi dari kolom tersebut.Kolom "dteday" yang awalnya memiliki tipe data string perlu diubah menjadi tipe data datetime.Pengubahan tipe data ini dapat dilakukan dengan menggunakan fungsi `pd.to_datetime()`.Setelah kolom "dteday" berhasil diubah menjadi tipe data datetime, data akan siap untuk tahap analisis lanjutan

# %%
df.dropna()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %%
df.drop_duplicates()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %%
df['dteday'] = pd.to_datetime(df['dteday'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Heatmap Korelasi Antara Kolom')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8472\2904943214.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=.5)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# dari 2 pertanyaan sebelumnya yang telah kita buat dilakukan analisis,disini saya menggunakan fungsi groupby untuk menggabungkan beberapa kolom untuk dapat dianalisis sehingga menjawab pertanyaan yang sudah ditentukan sebelumnya

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
df.groupby(by="season").instant.nunique().sort_values(ascending=False)
# Out:
# season
# 3    4496
# 2    4409
# 1    4242
# 4    4232
# Name: instant, dtype: int64

# %%
df.groupby(by="workingday").instant.nunique().sort_values(ascending=False)
# Out:
# workingday
# 1    11865
# 0     5514
# Name: instant, dtype: int64

# %%
df.groupby(by="mnth").instant.nunique()
# Out:
# mnth
# 1     1429
# 2     1341
# 3     1473
# 4     1437
# 5     1488
# 6     1440
# 7     1488
# 8     1475
# 9     1437
# 10    1451
# 11    1437
# 12    1483
# Name: instant, dtype: int64

# %%
df['workingday'] = df['workingday'].replace({1: 'not work ', 0: 'work'})
# df['mnth'] = df['mnth'].replace({1: 'Januari',
#                                  2: 'Februari',
#                                  3: 'Maret',
#                                  4: 'April',
#                                  5: 'Mei',
#                                  6:'Juni',
#                                  7:'Juli',
#                                  8:'Agustus',
#                                  9:'September',
#                                  10:'Oktober',
#                                  11:'November',
#                                  12:'Desember'
#                                  })
df['weekday'] = df['weekday'].replace({0: 'Monday',
                                       1: 'Tuesday',
                                       2: 'Wednesday',
                                       3: 'Thursday',
                                       4: 'Friday',
                                       5: 'Saturday',
                                       6: 'Sunday'})

# %%
workingday = df.groupby(by = ['mnth','workingday']).agg({

  'cnt' : 'sum'

})
workingday
# Out:
#                     cnt
# mnth workingday
# 1    not work     93916
#      work         41017
# 2    not work    111004
#      work         40348
# 3    not work    167063
#      work         61857
# 4    not work    179835
#      work         89259
# 5    not work    225835
#      work        105851
# 6    not work    241725
#      work        104617
# 7    not work    231430
#      work        113518
# 8    not work    271779
#      work         79415
# 9    not work    223627
#      work        122364
# 10   not work    220137
#      work        102215
# 11   not work    173961
#      work         80870
# 12   not work    152098
#      work         58938

# %%
df.groupby(by = ['weekday']).agg({
 'cnt' : 'sum'

})
# Out:
#               cnt
# weekday
# Friday     485395
# Monday     444027
# Saturday   487790
# Sunday     477807
# Thursday   473048
# Tuesday    455503
# Wednesday  469109

# %%
df.groupby(by="weekday").instant.nunique()
# Out:
# weekday
# Friday       2471
# Monday       2502
# Saturday     2487
# Sunday       2512
# Thursday     2475
# Tuesday      2479
# Wednesday    2453
# Name: instant, dtype: int64

# %%
season = df.groupby(by = ['season']).agg({

  'cnt' : 'sum'

})
workingday
# Out:
#                     cnt
# mnth workingday
# 1    not work     93916
#      work         41017
# 2    not work    111004
#      work         40348
# 3    not work    167063
#      work         61857
# 4    not work    179835
#      work         89259
# 5    not work    225835
#      work        105851
# 6    not work    241725
#      work        104617
# 7    not work    231430
#      work        113518
# 8    not work    271779
#      work         79415
# 9    not work    223627
#      work        122364
# 10   not work    220137
#      work        102215
# 11   not work    173961
#      work         80870
# 12   not work    152098
#      work         58938

# %%
season = df.groupby(by = ['season','mnth']).agg({

  'cnt' : 'sum'

})

season
# Out:
#                 cnt
# season mnth
# 1      1     134933
#        2     151352
#        3     142065
#        12     42998
# 2      3      86855
#        4     269094
#        5     331686
#        6     230954
# 3      6     115388
#        7     344948
#        8     351194
#        9     249599
# 4      9      96392
#        10    322352
#        11    254831
#        12    168038

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# Setelah menganalisis data dengan menggunakan fungsi groupby, langkah berikutnya adalah memvisualisasikan hasil analisis tersebut. Saya menggunakan grafik garis dan grafik batang untuk menggambarkan hasil temuan dari analisis yang telah dilakukan.

# %% [markdown]
# ### Pertanyaan 1:

# %%
workingday_pivot = workingday.reset_index().pivot(index='mnth', columns='workingday', values='cnt')

months_order = ['Januari', 'Februari', 'Maret', 'April', 'Mei', 'Juni', 'Juli', 'Agustus', 'September', 'Oktober', 'November', 'Desember']

plt.figure(figsize=(10, 6))
for category in workingday_pivot.columns:
    plt.plot(workingday_pivot.index, workingday_pivot[category], marker='o', label=category)

plt.title('Penggunaan Sepeda Motor per Bulan Berdasarkan Hari Kerja')
plt.xlabel('Bulan')
plt.ylabel('Jumlah')
plt.xticks(range(1, 13), months_order, rotation=45)
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
max_work = workingday.loc[workingday.index.get_level_values('workingday') == 'work'].max()
min_work = workingday.loc[workingday.index.get_level_values('workingday') == 'work'].min()
max_notwork = workingday.loc[workingday.index.get_level_values('workingday') == 'not work '].max()
min_notwork = workingday.loc[workingday.index.get_level_values('workingday') == 'not work '].min()


categories = ['Max Work', 'Min Work', 'Max Not Work', 'Min Not Work']
values = [max_work['cnt'], min_work['cnt'], max_notwork['cnt'], min_notwork['cnt']]

plt.figure(figsize=(8, 6))
bars = plt.bar(categories, values, color=['blue', 'blue', 'orange', 'orange'])


for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 10, value, ha='center', va='bottom')


plt.title('Jumlah Penggunaan Sepeda Motor Tertinggi dan Terendah Berdasarkan Hari Kerja')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
df['mnth'] = df['mnth'].replace({1: 'Januari',
                                 2: 'Februari',
                                 3: 'Maret',
                                 4: 'April',
                                 5: 'Mei',
                                 6:'Juni',
                                 7:'Juli',
                                 8:'Agustus',
                                 9:'September',
                                 10:'Oktober',
                                 11:'November',
                                 12:'Desember'
                                 })

# %%
season = df.groupby(by = ['season','mnth']).agg({

  'cnt' : 'sum'

})

season
# Out:
#                      cnt
# season mnth
# 1      Desember    42998
#        Februari   151352
#        Januari    134933
#        Maret      142065
# 2      April      269094
#        Juni       230954
#        Maret       86855
#        Mei        331686
# 3      Agustus    351194
#        Juli       344948
#        Juni       115388
#        September  249599
# 4      Desember   168038
#        November   254831
#        Oktober    322352
#        September   96392

# %%
season_totals = df.groupby('season')['cnt'].sum()

max_season = season_totals.idxmax()
min_season = season_totals.idxmin()

plt.figure(figsize=(10, 6))
bars = plt.bar(season_totals.index, season_totals.values, color=['blue', 'green', 'orange', 'red'])

plt.text(max_season, season_totals[max_season], f'{season_totals[max_season]}', ha='center', va='bottom')
plt.text(min_season, season_totals[min_season], f'{season_totals[min_season]}', ha='center', va='bottom')

plt.title('Total Penggunaan Sepeda Motor Berdasarkan Musim')
plt.xlabel('Musim')
plt.ylabel('Jumlah')


plt.xticks(season_totals.index, ['Musim Semi', 'Musim Panas', 'Musim Gugur', 'Musim Dingin'])

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
season_month_totals = df.groupby(['season', 'mnth'])['cnt'].sum()


all_months_season_totals = pd.DataFrame(index=range(1, 13))

for season in season_month_totals.index.get_level_values('season').unique():
    df['season'] = df['season'].replace({1: 'Semi',
                                 2: 'Panas',
                                 3: 'Gugur',
                                 4: 'Dingin',})
    all_months_season_totals[f'Musim {season}'] = season_month_totals[season]

plt.figure(figsize=(10, 6))

all_months_season_totals.plot(kind='bar', color=['blue', 'green', 'orange', 'red'])


plt.title('Total Penggunaan Sepeda Motor Berdasarkan Musim')
plt.xlabel('Bulan')
plt.ylabel('Jumlah')


plt.xticks(range(0, 12), ['Januari', 'Februari', 'Maret', 'April', 'Mei', 'Juni', 'Juli', 'Agustus', 'September', 'Oktober', 'November', 'Desember'], rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.legend(title='Musim')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
#     - Conclution pertanyaan 1
#         Berdasarkan hasil analisis, ditemukan perbedaan yang signifikan dalam jumlah penyewaan sepeda antara hari kerja dan hari libur. Visualisasi dalam bentuk diagram garis dan batang menunjukkan bahwa penyewaan sepeda lebih tinggi pada hari libur dibandingkan hari kerja. Jumlah penyewaan tertinggi pada hari libur mencapai 271.779, sedangkan pada hari kerja hanya 122.364.
#
#         Hasil ini mengindikasikan bahwa hari dalam seminggu, apakah hari kerja atau hari libur, berpengaruh secara signifikan terhadap pola penyewaan sepeda. Informasi ini penting bagi penyedia layanan untuk menyesuaikan strategi seperti penetapan harga, promosi, atau pengelolaan stok sepeda. Analisis ini juga menunjukkan bahwa masyarakat lebih sering menyewa sepeda pada hari libur, kemungkinan karena mereka memiliki waktu luang atau terlibat dalam aktivitas rekreasi pada hari tersebut.
#
#
#
#
#
#     - Conclution pertanyaan 2
#         Data menunjukkan adanya perbedaan signifikan dalam jumlah penyewaan sepeda antara musim gugur dan musim semi. Di musim gugur, penyewaan sepeda mencapai puncaknya dengan 1.061.129, sedangkan di musim semi jauh lebih rendah, yaitu 471.348. Hal ini menunjukkan bahwa musim berperan penting dalam memengaruhi keputusan masyarakat untuk menyewa sepeda.
#
#         Tingginya penyewaan sepeda di musim gugur mungkin dipengaruhi oleh cuaca yang lebih nyaman dan lingkungan yang lebih mendukung untuk aktivitas luar ruangan. Sebaliknya, pada musim semi, kondisi cuaca mungkin belum terlalu ideal bagi banyak orang untuk menyewa sepeda.
#
#         Temuan ini juga menunjukkan bahwa hari dalam seminggu, baik hari kerja maupun hari libur, memiliki dampak signifikan terhadap pola penyewaan sepeda. Perbedaan ini memberikan wawasan penting bagi penyedia layanan untuk menyesuaikan strategi seperti penetapan harga, promosi, dan pengelolaan stok sepeda. Selain itu, analisis ini juga mengungkap bahwa masyarakat lebih cenderung menyewa sepeda pada hari libur, kemungkinan karena mereka memiliki lebih banyak waktu luang untuk kegiatan rekreasi.
